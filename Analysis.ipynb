# %%
import pandas as pd

# %%
df = pd.read_csv('./NBA_Stats/player_stats.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 df = pd.read_csv('./NBA_Stats/player_stats.csv')
#
# File c:\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df.shape
# Out:
# (17210, 27)

# %%
df.describe()
# Out:
#        SEASON_ID  Player_ID  Game_ID  GAME_DATE  MATCHUP     WL    MIN    FGM  \
# count      17210      17210    17210      17210    17210  17210  17210  17210
# unique         2        494      792        107     1287      3     54     24
# top        22022  Player_ID  Game_ID  GAME_DATE  MATCHUP      L    MIN      1
# freq       16629        581      581        581      581   8331    581   2336
#
#           FGA FG_PCT  ...   DREB    REB    AST    STL    BLK    TOV     PF  \
# count   17210  17210  ...  17210  17210  17210  17210  17210  17210  17210
# unique     38    184  ...     22     27     20      9     10     13      8
# top         5    0.5  ...      1      2      0      0      0      0      1
# freq     1197   2149  ...   2892   2323   4410   9053  11490   6010   4061
#
#           PTS PLUS_MINUS VIDEO_AVAILABLE
# count   17210      17210           17210
# unique     61         86               2
# top         0          0               1
# ...

# %%
grouped = df.groupby("Player_ID")
grouped.head()
# Out:
#       SEASON_ID Player_ID     Game_ID     GAME_DATE      MATCHUP WL MIN FGM  \
# 0         22022   1630173  0022200789  FEB 03, 2023    TOR @ HOU  W  29   2
# 1         22022   1630173  0022200776  FEB 01, 2023    TOR @ UTA  L  25   6
# 2         22022   1630173  0022200762  JAN 30, 2023    TOR @ PHX  L  34   5
# 3         22022   1630173  0022200751  JAN 28, 2023    TOR @ POR  W  33  11
# 4         22022   1630173  0022200740  JAN 27, 2023    TOR @ GSW  L  36   8
# ...         ...       ...         ...           ...          ... ..  ..  ..
# 17157     22022   1627826  0022200784  FEB 02, 2023    LAC @ MIL  L  29   4
# 17158     22022   1627826  0022200766  JAN 31, 2023    LAC @ CHI  W  28   6
# 17159     22022   1627826  0022200754  JAN 29, 2023    LAC @ CLE  L  22   0
# 17160     22022   1627826  0022200745  JAN 28, 2023    LAC @ ATL  W  37   6
# 17161     22022   1627826  0022200735  JAN 26, 2023  LAC vs. SAS  W  21   4
#
# ...

# %%
df["Game Count"] = grouped["Game_ID"].cumcount() + 1

# %%
df.head()
# Out:
#   SEASON_ID Player_ID     Game_ID     GAME_DATE    MATCHUP WL MIN FGM FGA  \
# 0     22022   1630173  0022200789  FEB 03, 2023  TOR @ HOU  W  29   2   7
# 1     22022   1630173  0022200776  FEB 01, 2023  TOR @ UTA  L  25   6   8
# 2     22022   1630173  0022200762  JAN 30, 2023  TOR @ PHX  L  34   5   9
# 3     22022   1630173  0022200751  JAN 28, 2023  TOR @ POR  W  33  11  16
# 4     22022   1630173  0022200740  JAN 27, 2023  TOR @ GSW  L  36   8  12
#
#   FG_PCT  ... REB AST STL BLK TOV PF PTS PLUS_MINUS VIDEO_AVAILABLE Game Count
# 0  0.286  ...   8   2   1   1   2  6   9         -8               1          1
# 1   0.75  ...   6   1   1   1   0  4  13          3               1          2
# 2  0.556  ...  12   1   1   1   1  3  11         -6               1          3
# 3  0.688  ...  13   0   2   1   2  3  27         27               1          4
# 4  0.667  ...  11   2   1   0   2  2  17         -8               1          5
#
# [5 rows x 28 columns]

# %%
df.to_csv(f'./NBA_Stats/player_stats_GAMEInfo.csv')
